# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1 dimentional Series
mobile = pd.Series(['Samsung','iPhone','Nokia'])
mobile
# Out:
# 0    Samsung
# 1     iPhone
# 2      Nokia
# dtype: object

# %%
# 1-dimentional Series
bag = pd.Series(['pen','paper','notebook'])
bag
# Out:
# 0         pen
# 1       paper
# 2    notebook
# dtype: object

# %%
# 2 dimentional data
dataframe =pd.DataFrame({"electronic":mobile,'item':bag})
dataframe
# Out:
#   electronic      item
# 0    Samsung       pen
# 1     iPhone     paper
# 2      Nokia  notebook

# %%
#how to import Data
# Most common files format Csv comma seperated values
phone_csv = pd.read_csv("phone_data.csv")

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv.to_csv('modified_phone.csv', index=False)

# %%
phone_csv = pd.read_csv("modified_phone.csv")

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %% [markdown]
# # How to Describe Data

# %%
#Attributes
phone_csv.dtypes
#function()
# Out:
# Make          object
# Colour        object
# Memory(kb)     int64
# Sim Cards      int64
# Price         object
# dtype: object

# %%
phone_csv.columns
# Out:
# Index(['Make', 'Colour', 'Memory(kb)', 'Sim Cards', 'Price'], dtype='object')

# %%
phone_csv.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
phone_csv.describe()
# Out:
#           Memory(kb)  Sim Cards
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
phone_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Make        10 non-null     object
#  1   Colour      10 non-null     object
#  2   Memory(kb)  10 non-null     int64
#  3   Sim Cards   10 non-null     int64
#  4   Price       10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
phone_csv.mean(numeric_only=True)
# Out:
# Memory(kb)    78601.4
# Sim Cards         4.0
# dtype: float64

# %%
test = pd.Series([1,2,3])

# %%
mean_value = test.mean()

# %%
mean_value
# Out:
# np.float64(2.0)

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv['Sim Cards']
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Sim Cards, dtype: int64

# %%
phone_csv.head(8)
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00

# %%
phone_csv.tail(6)
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %% [markdown]
# # index (.loc) or Location (.iloc)

# %%
birds = pd.Series(['crow','pigion','parrot','wingedDonky','eagle'],index = [0,3,9,8,3])

# %%
birds
# Out:
# 0           crow
# 3         pigion
# 9         parrot
# 8    wingedDonky
# 3          eagle
# dtype: object

# %%
birds.loc[8]
# Out:
# 'wingedDonky'

# %%
birds.iloc[3]
# Out:
# 'wingedDonky'

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv.loc[3]
# Out:
# Make           iPhone
# Colour          Black
# Memory(kb)      11179
# Sim Cards           5
# Price         $220.00
# Name: 3, dtype: object

# %%
phone_csv.iloc[3]
# Out:
# Make           iPhone
# Colour          Black
# Memory(kb)      11179
# Sim Cards           5
# Price         $220.00
# Name: 3, dtype: object

# %%
phone_csv.iloc[:3]
# Out:
#       Make Colour  Memory(kb)  Sim Cards    Price
# 0    Nokia  White      150043          4  $400.00
# 1  Samsung    Red       87899          4  $500.00
# 2    Nokia   Blue       32549          3  $700.00

# %%
phone_csv.head(3)
# Out:
#       Make Colour  Memory(kb)  Sim Cards    Price
# 0    Nokia  White      150043          4  $400.00
# 1  Samsung    Red       87899          4  $500.00
# 2    Nokia   Blue       32549          3  $700.00

# %%
phone_csv['Make']
# Out:
# 0        Nokia
# 1      Samsung
# 2        Nokia
# 3       iPhone
# 4    Motorolla
# 5        Nokia
# 6      Samsung
# 7      Samsung
# 8        Nokia
# 9    Motorolla
# Name: Make, dtype: object

# %%
phone_csv.Make
# Out:
# 0        Nokia
# 1      Samsung
# 2        Nokia
# 3       iPhone
# 4    Motorolla
# 5        Nokia
# 6      Samsung
# 7      Samsung
# 8        Nokia
# 9    Motorolla
# Name: Make, dtype: object

# %%
phone_csv['Sim Cards']
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Sim Cards, dtype: int64

# %%
phone_csv.Sim cards # Does not work when there is space in the cloumn name
# Out:
#   Cell In[35], line 1
#     phone_csv.Sim cards # Does not work when there is space in the cloumn name
#                   ^
# SyntaxError: invalid syntax

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv[phone_csv["Colour"]=='White']
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 4  Motorolla  White      213095          4  $350.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv[phone_csv["Memory(kb)"] > 60000]
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00

# %% [markdown]
# # Data Selection 2

# %%
pd.crosstab(phone_csv["Memory(kb)"],phone_csv['Sim Cards'])
# Out:
# Sim Cards   3  4  5
# Memory(kb)
# 11179       0  0  1
# 31600       0  1  0
# 32549       1  0  0
# 45698       0  1  0
# 54738       0  1  0
# 60000       0  1  0
# 87899       0  1  0
# 99213       0  1  0
# 150043      0  1  0
# 213095      0  1  0

# %%
# more than two column for compare the command is groupby

phone_csv.groupby(['Make']).mean(numeric_only=True)
# Out:
#               Memory(kb)  Sim Cards
# Make
# Motorolla  122347.500000       4.00
# Nokia       85451.250000       3.75
# Samsung     62778.333333       4.00
# iPhone      11179.000000       5.00

# %%
phone_csv.dtypes
# Out:
# Make          object
# Colour        object
# Memory(kb)     int64
# Sim Cards      int64
# Price         object
# dtype: object

# %% [markdown]
# # How to plot Data

# %%
phone_csv['Memory(kb)'].plot()
# Out:
# <Axes: >

# %%
phone_csv['Sim Cards'].plot()
# Out:
# <Axes: >

# %%
phone_csv['Memory(kb)'].hist()
# Out:
# <Axes: >

# %%
phone_csv['Sim Cards'].hist()
# Out:
# <Axes: >

# %%
phone_csv['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 phone_csv['Price'].plot()
#
# File ~\Desktop\ml_project\venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\Desktop\ml_project\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\Desktop\ml_project\venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~\Desktop\ml_project\venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
phone_csv['Price']
# Out:
# 0    $400.00
# 1    $500.00
# 2    $700.00
# 3    $220.00
# 4    $350.00
# 5    $450.00
# 6    $750.00
# 7    $700.00
# 8    $625.00
# 9    $970.00
# Name: Price, dtype: object

# %% [markdown]
# # How to clean data

# %%
phone_csv = pd.read_csv("phone_data.csv")

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White      150043          4  $400.00
# 1    Samsung    Red       87899          4  $500.00
# 2      Nokia   Blue       32549          3  $700.00
# 3     iPhone  Black       11179          5  $220.00
# 4  Motorolla  White      213095          4  $350.00
# 5      Nokia  Green       99213          4  $450.00
# 6    Samsung   Blue       45698          4  $750.00
# 7    Samsung   Blue       54738          4  $700.00
# 8      Nokia  White       60000          4  $625.00
# 9  Motorolla  White       31600          4  $970.00

# %%
phone_csv["Price"] = phone_csv["Price"].astype(str)

# %%
phone_csv["Price"] = phone_csv["Price"].str.replace(r'[$.]', '', regex=True).fillna('0').astype(int)

# %%
phone_csv["Price"]
# Out:
# 0    40000
# 1    50000
# 2    70000
# 3    22000
# 4    35000
# 5    45000
# 6    75000
# 7    70000
# 8    62500
# 9    97000
# Name: Price, dtype: int64

# %%
phone_csv['Price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Changing Data

# %%
phone_csv['Colour'].str.lower()
# Out:
# 0    white
# 1      red
# 2     blue
# 3    black
# 4    white
# 5    green
# 6     blue
# 7     blue
# 8    white
# 9    white
# Name: Colour, dtype: object

# %% [markdown]
# ## How to fill missing values

# %%
phone_csv_missing = pd.read_csv('phone_data_missing_values.csv')

# %%
phone_csv_missing
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White    150043.0          4  $400.00
# 1    Samsung    Red     87899.0          4  $500.00
# 2      Nokia    NaN         NaN          3      NaN
# 3     iPhone  Black     11179.0          5  $220.00
# 4  Motorolla  White    213095.0          4  $350.00
# 5      Nokia    NaN         NaN          4      NaN
# 6    Samsung   Blue     45698.0          4  $750.00
# 7    Samsung   Blue         NaN          4  $700.00
# 8        NaN  White     60000.0          4  $625.00
# 9  Motorolla  White     31600.0          4  $970.00

# %%
phone_csv_missing.fillna({'Memory(kb)': phone_csv_missing['Memory(kb)'].mean()}, inplace=True)

# %%
phone_csv_missing
# Out:
#         Make Colour     Memory(kb)  Sim Cards    Price
# 0      Nokia  White  150043.000000          4  $400.00
# 1    Samsung    Red   87899.000000          4  $500.00
# 2      Nokia    NaN   85644.857143          3      NaN
# 3     iPhone  Black   11179.000000          5  $220.00
# 4  Motorolla  White  213095.000000          4  $350.00
# 5      Nokia    NaN   85644.857143          4      NaN
# 6    Samsung   Blue   45698.000000          4  $750.00
# 7    Samsung   Blue   85644.857143          4  $700.00
# 8        NaN  White   60000.000000          4  $625.00
# 9  Motorolla  White   31600.000000          4  $970.00

# %%
phone_csv_missing.dropna(inplace=True)

# %%
phone_csv_missing
# Out:
#         Make Colour     Memory(kb)  Sim Cards    Price
# 0      Nokia  White  150043.000000          4  $400.00
# 1    Samsung    Red   87899.000000          4  $500.00
# 3     iPhone  Black   11179.000000          5  $220.00
# 4  Motorolla  White  213095.000000          4  $350.00
# 6    Samsung   Blue   45698.000000          4  $750.00
# 7    Samsung   Blue   85644.857143          4  $700.00
# 9  Motorolla  White   31600.000000          4  $970.00

# %%
phone_csv_missing = pd.read_csv('phone_data_missing_values.csv')

# %%
phone_csv_missing.dropna(inplace=True)

# %%
phone_csv_missing
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White    150043.0          4  $400.00
# 1    Samsung    Red     87899.0          4  $500.00
# 3     iPhone  Black     11179.0          5  $220.00
# 4  Motorolla  White    213095.0          4  $350.00
# 6    Samsung   Blue     45698.0          4  $750.00
# 9  Motorolla  White     31600.0          4  $970.00

# %%
phone_csv_missing.to_csv('Cleaned_data.csv')

# %% [markdown]
# ## Add Remove and Change Columns

# %%
phone_csv = pd.read_csv('Cleaned_data.csv')

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price
# 0           0      Nokia  White    150043.0          4  $400.00
# 1           1    Samsung    Red     87899.0          4  $500.00
# 2           3     iPhone  Black     11179.0          5  $220.00
# 3           4  Motorolla  White    213095.0          4  $350.00
# 4           6    Samsung   Blue     45698.0          4  $750.00
# 5           9  Motorolla  White     31600.0          4  $970.00

# %%
battries = pd.Series([3,4,5,6,7])
phone_csv['battery'] = battries

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      NaN

# %%
phone_csv.fillna({'battery':5},inplace=True)

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0

# %%
ringtones = [1,2,5,6,8,9]
phone_csv['Ringtones'] = ringtones

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery  \
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0
#
#    Ringtones
# 0          1
# 1          2
# 2          5
# 3          6
# 4          8
# 5          9

# %%
phone_csv['Product'] = phone_csv['battery']*phone_csv['Ringtones']

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery  \
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0
#
#    Ringtones  Product
# 0          1      3.0
# 1          2      8.0
# 2          5     25.0
# 3          6     36.0
# 4          8     56.0
# 5          9     45.0

# %%
phone_csv['New_col']=3

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery  \
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0
#
#    Ringtones  Product  New_col
# 0          1      3.0        3
# 1          2      8.0        3
# 2          5     25.0        3
# 3          6     36.0        3
# 4          8     56.0        3
# 5          9     45.0        3

# %%
phone_csv['Safety']= True

# %%
phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery  \
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0
#
#    Ringtones  Product  New_col  Safety
# 0          1      3.0        3    True
# 1          2      8.0        3    True
# 2          5     25.0        3    True
# 3          6     36.0        3    True
# 4          8     56.0        3    True
# 5          9     45.0        3    True

# %%
 phone_csv.drop('New_col',axis=1,inplace=True)

# %%
 phone_csv
# Out:
#    Unnamed: 0       Make Colour  Memory(kb)  Sim Cards    Price  battery  \
# 0           0      Nokia  White    150043.0          4  $400.00      3.0
# 1           1    Samsung    Red     87899.0          4  $500.00      4.0
# 2           3     iPhone  Black     11179.0          5  $220.00      5.0
# 3           4  Motorolla  White    213095.0          4  $350.00      6.0
# 4           6    Samsung   Blue     45698.0          4  $750.00      7.0
# 5           9  Motorolla  White     31600.0          4  $970.00      5.0
#
#    Ringtones  Product  Safety
# 0          1      3.0    True
# 1          2      8.0    True
# 2          5     25.0    True
# 3          6     36.0    True
# 4          8     56.0    True
# 5          9     45.0    True

# %% [markdown]
# ## Manipulating Datam
# # shapling

# %%
phone_csv = pd.read_csv("Cleaned_data.csv")

# %%
phone_csv.drop('Unnamed: 0', axis=1, inplace=True)

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White    150043.0          4  $400.00
# 1    Samsung    Red     87899.0          4  $500.00
# 2     iPhone  Black     11179.0          5  $220.00
# 3  Motorolla  White    213095.0          4  $350.00
# 4    Samsung   Blue     45698.0          4  $750.00
# 5  Motorolla  White     31600.0          4  $970.00

# %%
phone_csv.sample(frac=1)
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 4    Samsung   Blue     45698.0          4  $750.00
# 0      Nokia  White    150043.0          4  $400.00
# 1    Samsung    Red     87899.0          4  $500.00
# 2     iPhone  Black     11179.0          5  $220.00
# 5  Motorolla  White     31600.0          4  $970.00
# 3  Motorolla  White    213095.0          4  $350.00

# %%
 phone_csv.reset_index(drop=True,inplace=True)

# %%
 phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White    150043.0          4  $400.00
# 1    Samsung    Red     87899.0          4  $500.00
# 2     iPhone  Black     11179.0          5  $220.00
# 3  Motorolla  White    213095.0          4  $350.00
# 4    Samsung   Blue     45698.0          4  $750.00
# 5  Motorolla  White     31600.0          4  $970.00

# %%
 phone_csv['Memory(kb)'] = phone_csv['Memory(kb)'].apply(lambda x:x/1000)

# %%
phone_csv
# Out:
#         Make Colour  Memory(kb)  Sim Cards    Price
# 0      Nokia  White     150.043          4  $400.00
# 1    Samsung    Red      87.899          4  $500.00
# 2     iPhone  Black      11.179          5  $220.00
# 3  Motorolla  White     213.095          4  $350.00
# 4    Samsung   Blue      45.698          4  $750.00
# 5  Motorolla  White      31.600          4  $970.00
